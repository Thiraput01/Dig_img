# %% [markdown]
# <a href="https://colab.research.google.com/github/Thiraput01/Dig_img/blob/main/1_Image_Processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week #1 Intro
# ## Exercise #1: read and show an image, get pixel values
# * skimage.io
# * cv2

# %% [markdown]
# * Download "kitty.jpg" image

# %%
# !wget https://drive.google.com/uc?id=1Yox-XWM-PY9vFtDdzB_y_U3SK2paewwe -O kitty.jpg
# Out:
# --2024-08-07 06:24:07--  https://drive.google.com/uc?id=1Yox-XWM-PY9vFtDdzB_y_U3SK2paewwe
# Resolving drive.google.com (drive.google.com)... 108.177.127.139, 108.177.127.138, 108.177.127.101, ...
# Connecting to drive.google.com (drive.google.com)|108.177.127.139|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1Yox-XWM-PY9vFtDdzB_y_U3SK2paewwe [following]
# --2024-08-07 06:24:07--  https://drive.usercontent.google.com/download?id=1Yox-XWM-PY9vFtDdzB_y_U3SK2paewwe
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 172.217.218.132, 2a00:1450:4013:c08::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|172.217.218.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 79570 (78K) [image/jpeg]
# Saving to: ‘kitty.jpg’
#
# kitty.jpg           100%[===================>]  77.71K  --.-KB/s    in 0.001s
#
# 2024-08-07 06:24:10 (82.6 MB/s) - ‘kitty.jpg’ saved [79570/79570]

# %% [markdown]
# * Read and show image using skimage.io

# %%
from skimage import io, color
img = io.imread("kitty.jpg")
io.imshow(img)
io.show()

import matplotlib.pyplot as plt
plt.imshow(img[:,:,0])
plt.show()

# %% [markdown]
# * Display some part of the image

# %%
# TO DO: show some part of the image
some_img = img[100:400,100:400]
plt.imshow(some_img)
plt.show()

# %% [markdown]
# * Read and display using cv2

# %%
import cv2
image2 = cv2.imread("kitty.jpg")


plt.imshow(image2)
plt.axis('off')
plt.show()

# TO DO: show the image properly
plt.imshow(cv2.cvtColor(image2, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %% [markdown]
# ## Exercise #2 Dicom file
# DICOM® — Digital Imaging and Communications in Medicine — is the international standard for medical images and related information. It defines the formats for medical images that can be exchanged with the data and quality necessary for clinical use.
#
# Ref. https://www.dicomstandard.org
#
# * What is the image size?
# * What is the datatype of pixel_array ?
# * Min/max?
# * Try with “MR_small.dcm”

# %%
# !pip install pydicom
# Out:
# Collecting pydicom
#   Downloading pydicom-2.4.4-py3-none-any.whl.metadata (7.8 kB)
# Downloading pydicom-2.4.4-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 30.7 MB/s eta 0:00:00
# Installing collected packages: pydicom
# Successfully installed pydicom-2.4.4

# %%
import matplotlib.pyplot as plt
from pydicom import dcmread
from pydicom.data import get_testdata_file


fpath = get_testdata_file('MR_small.dcm')
ds = dcmread(fpath)

print(f"Patient's Name...: {ds.PatientName}")
print(f"Patient ID.......: {ds.PatientID}")
print(f"Modality.........: {ds.Modality}")
print(f"Study Date.......: {ds.StudyDate}")
print(f"Image size.......: {ds.Rows} x {ds.Columns}")
print(f"Pixel Spacing....: {ds.PixelSpacing}")

# plot the image using matplotlib
plt.imshow(ds.pixel_array, cmap=plt.cm.gray)
plt.show()
# Out:
# Patient's Name...: CompressedSamples^MR1
# Patient ID.......: 4MR1
# Modality.........: MR
# Study Date.......: 20040826
# Image size.......: 64 x 64
# Pixel Spacing....: [0.3125, 0.3125]

# %%
print(ds.pixel_array.dtype)
print(ds.pixel_array.min())
print(ds.pixel_array.max())
# Out:
# int16
# 127
# 2145

# %%
ds.pixel_array
# Out:
# array([[ 905, 1019, 1227, ...,  302,  304,  328],
#        [ 628,  770,  907, ...,  298,  331,  355],
#        [ 498,  566,  706, ...,  280,  285,  320],
#        ...,
#        [ 334,  400,  431, ..., 1094, 1068, 1083],
#        [ 339,  377,  413, ..., 1318, 1346, 1336],
#        [ 378,  374,  422, ..., 1369, 1129,  862]], dtype=int16)

# %% [markdown]
# ## Exercise #3 Image Color Visualization
# * 0 is always black?
# * 255 is  always white?

# %%
import numpy as np
a = np.array([ [100,200],[100,200] ])
# TO DO: show image a
plt.title("a")
plt.imshow(a)
plt.show()


b = np.array([ [0.5,0.7],[0.9,1.0]] )
# TO DO: show image b
plt.title("b")
plt.imshow(b)
plt.show()

# %% [markdown]
# ## Exercises # 4
# Create  an image of 100x100 which has red color on the half left and cyan color on the half right and display the image

# %%
import numpy as np
import matplotlib.pyplot as plt

red = [255, 0, 0]
cyan = [0, 255, 255]

img = np.zeros((100, 100, 3), dtype=np.uint8)
img[:, :50] = red
img[:, 50:] = cyan

plt.imshow(img)
plt.show()
